# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()
client = Anthropic()
model = "claude-sonnet-4-6"

def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})

def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})

def chat(messages):
    response = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return response.content[0].text


# Make an initial list of messages
messages = []

# Use a 'While True' loop to run the chatbot forever
while True:
    # Get user input
    user_input = input("> ")
    print(">", user_input)

    # Add user input to the list of messages
    add_user_message(messages, user_input)
    # Call Claude with the 'chat' function
    answer = chat(messages)
    # Add generated text to the list of messages
    add_assistant_message(messages, answer)
    # Print the generated text
    print("---")
    print(answer)
    print("---")
# Out:
# > What is Highway
# ---
# # Highway
#
# A **highway** is a major public road designed for high-speed travel between cities, towns, or regions. Here are the key aspects:
#
# ## Basic Definition
# A highway is a **main road** that connects different locations, typically built to accommodate large volumes of traffic at relatively high speeds.
#
# ## Types of Highways
#
# | Type | Description |
# |------|-------------|
# | **Freeway/Expressway** | Controlled access, no traffic lights or intersections |
# | **Interstate Highway** | Connects multiple states (e.g., US Interstate system) |
# | **National Highway** | Connects major cities within a country |
# | **State/Provincial Highway** | Managed by state or provincial governments |
# | **Tollway** | Requires payment to use |
#
# ## Key Features
# - **Multiple lanes** for traffic flow
# - **Speed limits** (usually higher than regular roads)
# - **On/off ramps** for controlled access
# - **Road signs and markings**
# - **Median dividers** on major highways
#
# ## Purpose
# - Connect cities and regions
# - Facilitate trade and commerce
# - Enable faster transportation
# - Support economic development
#
# ## Examples
# - **US Interstate Highway System**
# - **Germany's Autobahn**
# - **India's National Highways**
# - **China's Expressway Network**
#
# Highways are a critical part of a country's **transportation infrastructure**.
#
# Would you like to know more about any specific aspect?
# ---
# >
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[1], line 35
#      31
#      32     # Add user input to the list of messages
#      33     add_user_message(messages, user_input)
#      34     # Call Claude with the 'chat' function
# ---> 35     answer = chat(messages)
#      36     # Add generated text to the list of messages
#      37     add_assistant_message(messages, answer)
#      38     # Print the generated text
#
# Cell In[1], line 15, in chat(messages)
#      14 def chat(messages):
# ---> 15     response = client.messages.create(
#      16         model=model,
#      17         max_tokens=1000,
#      18         messages=messages,
#
# File c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages\anthropic\resources\messages\messages.py:1050, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1043     warnings.warn(
#    1044         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1045         UserWarning,
#    1046         stacklevel=3,
#    1047     )
#    1049 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1050 return self._post(
#    1051     "/v1/messages",
#    1052     body=maybe_transform(
#    1053         {
#    1054             "max_tokens": max_tokens,
#    1055             "messages": messages,
#    1056             "model": model,
#    1057             "cache_control": cache_control,
#    1058             "container": container,
#    1059             "inference_geo": inference_geo,
#    1060             "metadata": metadata,
#    1061             "output_config": output_config,
#    1062             "service_tier": service_tier,
#    1063             "stop_sequences": stop_sequences,
#    1064             "stream": stream,
#    1065             "system": system,
#    1066             "temperature": temperature,
#    1067             "thinking": thinking,
#    1068             "tool_choice": tool_choice,
#    1069             "tools": tools,
#    1070             "top_k": top_k,
#    1071             "top_p": top_p,
#    1072         },
#    1073         message_create_params.MessageCreateParamsStreaming
#    1074         if stream
#    1075         else message_create_params.MessageCreateParamsNonStreaming,
#    1076     ),
#    1077     options=make_request_options(
#    1078         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1079     ),
#    1080     cast_to=Message,
#    1081     stream=stream or False,
#    1082     stream_cls=Stream[RawMessageStreamEvent],
#    1083 )
#
# File c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages\anthropic\_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages\anthropic\_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.2: user messages must have non-empty content'}, 'request_id': 'req_011CcfQcSAbGR1vhvJV3sWEF'}
