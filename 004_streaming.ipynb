# %%
# Install the required packages and load the environment variables
# %pip install anthropic
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()
client = Anthropic()
model = "claude-sonnet-4-6"
# Out:
# Requirement already satisfied: anthropic in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.115.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in C:\Users\Reza Paramarta\AppData\Roaming\Python\Python311\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Reza Paramarta\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Helper functions to manage messages and interact with the API
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }

    if system:
        params["system"] = system
    message = client.messages.create(**params)
    return message.content[0].text

# %%
# list of messages
messages = []

add_user_message(messages, "Write a 1 sentence description of a fake database")

stream = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=messages,
    stream=True,
)

for event in stream:
    print(event)
# Out:
# RawMessageStartEvent(message=Message(id='msg_019yzoKMLK3R6MQF7dMH6wBn', container=None, content=[], model='claude-sonnet-4-6', role='assistant', stop_details=None, stop_reason=None, stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=18, output_tokens=1, output_tokens_details=None, server_tool_use=None, service_tier='standard')), type='message_start')
# RawContentBlockStartEvent(content_block=TextBlock(citations=None, text='', type='text'), index=0, type='content_block_start')
# RawContentBlockDeltaEvent(delta=TextDelta(text='Here', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' is a 1 sentence description of a fake database:\n\n**NebulaDB** is a fictional cloud', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='-based relational database management system that stores and organizes data across distributed', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text=' servers using a proprietary query language called NebQL.', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockStopEvent(index=0, type='content_block_stop')
# RawMessageDeltaEvent(delta=Delta(container=None, stop_details=None, stop_reason='end_turn', stop_sequence=None), type='message_delta', usage=MessageDeltaUsage(cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=18, output_tokens=55, output_tokens_details=None, server_tool_use=None))
# RawMessageStopEvent(type='message_stop')

# %%
# New List of Messages
messages = []

add_user_message(messages, "Write a 1 sentence description of a fake database")

with client.messages.stream(
    model=model,
    max_tokens=1000,
    messages=messages,
) as stream:
    for text in stream.text_stream:
        #print(text, end="")
        pass

stream.get_final_message()
# Out:
# ParsedMessage(id='msg_013WVcSdet6m5KXv5rvJ2HUH', container=None, content=[ParsedTextBlock(citations=None, text='Here is a 1 sentence description of a fake database:\n\n**FruityBase** is a fictional database containing detailed records of over 10,000 imaginary exotic fruits, including their made-up nutritional values, fantasy origin planets, and whimsical flavor descriptions written by a team of fictional food scientists.', type='text', parsed_output=None)], model='claude-sonnet-4-6', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=18, output_tokens=71, output_tokens_details=None, server_tool_use=None, service_tier='standard'))
